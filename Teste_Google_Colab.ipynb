# %% [markdown]
# <a href="https://colab.research.google.com/github/caleberosa/GoogleColab/blob/main/Teste_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

url = "https://sim.native-infinity.com.br/api/users"

payload = json.dumps({
  "username": "60",
  "password": "6012Dw"
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6ODA5LCJwZXJtaXNzaW9ucyI6WyJyZXBvcnRzIiwiY29ja3BpdCIsImNhbGxjZW50ZXIiLCJwZWVyc1BhbmVsIiwicmVwb3J0c0l2cnMiLCJyZXBvcnRzUmVjb3JkcyIsInN1cGVydmlzb3IiXSwiaXNBZG1pbiI6ZmFsc2UsImV4cGlyYXRpb24iOjE3NTY1NzY2MjEzMTl9.idznEkfzGUpYLgtm8fnilPJjCk0CxRvZB_wye9a2T-I'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"id":1,"name":"Admin","username":"native","email":"suporte@nativeip.com.br","password":"$2b$10$l02FyE8dFn7eEqHcOIJNp.q6yPdgSCVXoeQHilgnVJeCoK..oNBHW","callcenter":"supervisor","avatar":"49-call-center.png","administrator":true,"superAdministrator":true,"status":"Offline","ringtone":null,"passwordCall":null,"chatWebDefault":false,"dialer":"no","externalRingtone":null,"absenceTemporary":false,"disableChat":false,"homePage":"serverInfo","disableSoftphone":false,"queueLock":false,"configurations":"{\"dashboardViewAgents\":\"cards\",\"queueSelection\":[{\"name\":\"CHARRUA - BACKOFFICE\",\"id\":29,\"incoming\":true,\"outgoing\":true},{\"name\":\"CSC - Financeiro Cartões\",\"id\":80,\"incoming\":true,\"outgoing\":true},{\"name\":\"CSC - Rh - Adm Gente Admissões\",\"id\":77,\"incoming\":true,\"outgoing\":true},{\"name\":\"CSC - Rh - Adm. Gente - Beneficios\",\"id\":76,\"incoming\":true,\"outgoing\":true},{\"name\":\"CSC - Rh - Adm. Gente Atendentes\",\"id\":79,\"incoming\":true,\"outgoing\
# ...

# %%
import requests
import pandas as pd
import json
from google.colab import userdata

url = "https://sim.native-infinity.com.br/api/groups"

payload = {}
headers = {
    'Authorization': 'Bearer ' +  userdata.get('Native')
}

response = requests.request("GET", url, headers=headers, data=payload, verify=False)

jdata = json.loads(response.text)

df = pd.DataFrame(jdata)
print(df)
# Out:
#     id                                 name description      createdBy  \
# 0    1                    Charrua - Direção     Charrua         native
# 1    2                       Charrua - Base        None         native
# 2    3         Charrua - Cadastro/Comercial        None         native
# 3    4                    Charrua - Compras        None         native
# 4    5                 Charrua - Financeiro        None         native
# ..  ..                                  ...         ...            ...
# 56  60  SIM REDE DE POSTOS - Relacionamento        None  admin.charrua
# 57  61  SIM REDE DE POSTOS - Compras Varejo        None  admin.charrua
# 58  62    SIM REDE DE POSTOS - Ciclo Diesel        None  admin.charrua
# 59  63      SIM REDE DE POSTOS - Ciclo Otto        None  admin.charrua
# 60  64         CSC - Excelência Operacional        None  admin.charrua
#
#         updatedBy lockGroup lockGroupType  lockGroupValue  \
# ...
